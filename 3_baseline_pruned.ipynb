# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm 
from sklearn.model_selection import train_test_split

import torch
import spacy
from torch import nn, optim
from transformers import pipeline
from functools import partial

nlp = spacy.load("en_core_web_trf")
# Out:
# /home/ytchen/.local/lib/python3.8/site-packages/spacy/util.py:730: UserWarning: [W095] Model 'en_core_web_trf' (3.0.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.1.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
imdb_data=pd.read_csv('./data/processed_train.csv')
print(imdb_data.shape)
imdb_data.head(5)
# Out:
# (29341, 4)
#       ID                                             review sentiment  \
# 0  41411  I watched this film because I'm a big fan of R...         0
# 1  37586  It does not seem that this movie managed to pl...         1
# 2   6017        Enough is not a bad movie , just mediocre .         0
# 3  44656  my friend and i rented this one a few nights a...         0
# 4  38711  Just about everything in this movie is wrong, ...         0
#
#                                     processed_review
# 0  watch film m big fan river phoenix joaquin pho...
# 1  movie manage lot people see place bump acciden...
# 2                                 bad movie mediocre
# 3  friend rent night ago single good movie see me...
# 4  movie wrong wrong wrong mike myers example s r...

# %%
imdb_test_data=pd.read_csv('./data/processed_test.csv')
print(imdb_test_data.shape)
imdb_test_data.head(5)
# Out:
# (29341, 3)
#       ID                                             review  \
# 0  22622  Robert Lansing plays a scientist experimenting...
# 1  10162  Well I've enjoy this movie, even though someti...
# 2  17468  First things first - though I believe Joel Sch...
# 3  42579  I watched this movie on the grounds that Amber...
# 4    701  A certain sexiness underlines even the dullest...
#
#                                     processed_review
# 0  robert lansing play scientist experiment pass ...
# 1  ve enjoy movie turn stereotypical situation nt...
# 2  thing believe joel schumacher well mediocre di...
# 3  watch movie ground amber benson rock nick stah...
# 4            certain sexiness underline dull tangent

# %%
MAX_LEN = 512

# %%
all_review = list(map(str, np.concatenate([imdb_data.processed_review.values, imdb_test_data.processed_review.values])))
train_review = list(map(str, imdb_data.processed_review.values))
test_review = list(map(str, imdb_test_data.processed_review.values))

# %% [markdown]
# #### produce column : pruned_review

# %% [markdown]
# if input documents are longer than 512 tokens, sentiment analysis pipeline is not out of box. so, we need to prune reviews first.

# %% [markdown]
# Our preprocessing pipeline : tokenize -> remove stopwords -> choose words where pos like adj, adv, propn etc., these words are representative.

# %%
def prune_text(text, MAX_LEN):
    doc = nlp(text)
    lst = []
    for token in doc:
        # print(token, token.pos_)
        if token.pos_ in ('ADJ','ADV','CONJ','CCONJ','PART','PROPN'):
            lst.append(token.orth_)
    if len(lst) > MAX_LEN:
        lst = lst[:MAX_LEN]

    return " ".join(lst)

# processed_text = list(map(partial(prune_text, MAX_LEN=MAX_LEN), list(train_review)))
# imdb_data['pruned_review'] = processed_text
# imdb_data.to_csv('./data/processed_train.csv',index=0)

# processed_text = list(map(partial(prune_text, MAX_LEN=MAX_LEN), list(test_review)))
# imdb_test_data['pruned_review'] = processed_text
# imdb_data.to_csv('./data/processed_test.csv',index=0)

# %%
# https://towardsdatascience.com/sentiment-analysis-with-pretrained-transformers-using-pytorch-420bbc1a48cd
sentiment_analysis = pipeline("sentiment-analysis")

# %%
classifier = pipeline('sentiment-analysis')
results = classifier(["We are very happy to show you the 🤗 Transformers library.",
           "We hope you don't hate it."])
for result in results:
    print(f"label: {result['label']}, with score: {round(result['score'], 4)}")
# Out:
# label: POSITIVE, with score: 0.9998
# label: NEGATIVE, with score: 0.5309

# %%
s = "I'm extremely excited but today weather is not good."
print(s)
sentiment_analysis(s)[0]
# Out:
# I'm extremely excited but today weather is not good.
# {'label': 'NEGATIVE', 'score': 0.9990981817245483}

# %%
s1 = prune_text(s, MAX_LEN=MAX_LEN)
print(s1)
sentiment_analysis(s1)[0]
# Out:
# extremely excited but not good
# {'label': 'NEGATIVE', 'score': 0.9929606914520264}

# %%
imdb_data['processed_review'] = imdb_data['processed_review'].astype(str)

# %%
pruned = []
for txt in tqdm(imdb_data['processed_review']):
    pruned.append(prune_text(txt, MAX_LEN=MAX_LEN))
# Out:
# 100%|██████████| 29341/29341 [1:08:54<00:00,  7.10it/s]

# %%
imdb_data['pruned_review'] = pruned

# %%
imdb_data
# Out:
#           ID                                             review sentiment  \
# 0      41411  I watched this film because I'm a big fan of R...         0
# 1      37586  It does not seem that this movie managed to pl...         1
# 2       6017        Enough is not a bad movie , just mediocre .         0
# 3      44656  my friend and i rented this one a few nights a...         0
# 4      38711  Just about everything in this movie is wrong, ...         0
# ...      ...                                                ...       ...
# 29336   8019  It 's one of the most honest films ever made a...         1
# 29337    453  An absorbing and unsettling psychological drama .         1
# 29338  13097  Soylent Green IS...a really good movie, actual...         1
# 29339  26896  There just isn't enough here. There a few funn...         0
# 29340  27094  This show was absolutely terrible. For one Geo...         0
#
#                                         processed_review  \
# 0      watch film m big fan river phoenix joaquin pho...
# 1      movie manage lot people see place bump acciden...
# 2                                     bad movie mediocre
# 3      friend rent night ago single good movie see me...
# 4      movie wrong wrong wrong mike myers example s r...
# ...                                                  ...
# 29336                            s honest film hollywood
# 29337              absorb unsettling psychological drama
# 29338  soylent green good movie actually ve think don...
# 29339  isn funny spot disappoint love stupid movie ex...
# 29340  absolutely terrible george isn funny kid snobb...
#
#                                            pruned_review
# 0      river phoenix joaquin phoenix embarrasing weir...
# 1      usually great crazy pretty mr jones different ...
# 2                                           bad mediocre
# 3      ago single good close wonderfuly original usua...
# 4      wrong wrong myers ago cutesy painfully unfunny...
# ...                                                  ...
# 29336                                   honest hollywood
# 29337                    absorb unsettling psychological
# 29338  soylent green good actually heston sneery invi...
# 29339  isn funny stupid good loud maybe funny flat ma...
# 29340  absolutely terrible george funny snobby little...
#
# [29341 rows x 5 columns]

# %%
imdb_data.to_csv('./data/pruned_train.csv', index=0)

# %%
imdb_data['pruned_review'] = imdb_data['pruned_review'].astype(str)

# %%
result = []
score = []
for txt in tqdm(imdb_data['pruned_review']):
    result.append('0' if sentiment_analysis(txt)[0]['label'] == 'NEGATIVE' else '1')
    score.append(sentiment_analysis(txt)[0]['score'])
# Out:
# 100%|██████████| 29341/29341 [25:15<00:00, 19.36it/s]

# %%
imdb_data['pred_sentiment'] = result
imdb_data['score'] = score
# Out:
#           ID                                             review sentiment  \
# 0      41411  I watched this film because I'm a big fan of R...         0
# 1      37586  It does not seem that this movie managed to pl...         1
# 2       6017        Enough is not a bad movie , just mediocre .         0
# 3      44656  my friend and i rented this one a few nights a...         0
# 4      38711  Just about everything in this movie is wrong, ...         0
# ...      ...                                                ...       ...
# 29336   8019  It 's one of the most honest films ever made a...         1
# 29337    453  An absorbing and unsettling psychological drama .         1
# 29338  13097  Soylent Green IS...a really good movie, actual...         1
# 29339  26896  There just isn't enough here. There a few funn...         0
# 29340  27094  This show was absolutely terrible. For one Geo...         0
#
#                                         processed_review  \
# 0      watch film m big fan river phoenix joaquin pho...
# 1      movie manage lot people see place bump acciden...
# 2                                     bad movie mediocre
# 3      friend rent night ago single good movie see me...
# 4      movie wrong wrong wrong mike myers example s r...
# ...                                                  ...
# 29336                            s honest film hollywood
# 29337              absorb unsettling psychological drama
# 29338  soylent green good movie actually ve think don...
# 29339  isn funny spot disappoint love stupid movie ex...
# 29340  absolutely terrible george isn funny kid snobb...
#
#                                            pruned_review pred_sentiment  \
# 0      river phoenix joaquin phoenix embarrasing weir...              0
# 1      usually great crazy pretty mr jones different ...              1
# 2                                           bad mediocre              0
# 3      ago single good close wonderfuly original usua...              1
# 4      wrong wrong myers ago cutesy painfully unfunny...              0
# ...                                                  ...            ...
# 29336                                   honest hollywood              1
# 29337                    absorb unsettling psychological              0
# 29338  soylent green good actually heston sneery invi...              1
# 29339  isn funny stupid good loud maybe funny flat ma...              0
# 29340  absolutely terrible george funny snobby little...              0
#
#           score
# 0      0.984501
# 1      0.999685
# 2      0.999798
# 3      0.999860
# 4      0.973535
# ...         ...
# 29336  0.999783
# 29337  0.854891
# 29338  0.997482
# 29339  0.997078
# 29340  0.996091
#
# [29341 rows x 7 columns]

# %%
# filtered weird sentiment data
imdb_data = imdb_data[~imdb_data['sentiment'].str.contains('[A-Za-z]')]
imdb_data
# Out:
#           ID                                             review sentiment  \
# 0      41411  I watched this film because I'm a big fan of R...         0
# 1      37586  It does not seem that this movie managed to pl...         1
# 2       6017        Enough is not a bad movie , just mediocre .         0
# 3      44656  my friend and i rented this one a few nights a...         0
# 4      38711  Just about everything in this movie is wrong, ...         0
# ...      ...                                                ...       ...
# 29336   8019  It 's one of the most honest films ever made a...         1
# 29337    453  An absorbing and unsettling psychological drama .         1
# 29338  13097  Soylent Green IS...a really good movie, actual...         1
# 29339  26896  There just isn't enough here. There a few funn...         0
# 29340  27094  This show was absolutely terrible. For one Geo...         0
#
#                                         processed_review  \
# 0      watch film m big fan river phoenix joaquin pho...
# 1      movie manage lot people see place bump acciden...
# 2                                     bad movie mediocre
# 3      friend rent night ago single good movie see me...
# 4      movie wrong wrong wrong mike myers example s r...
# ...                                                  ...
# 29336                            s honest film hollywood
# 29337              absorb unsettling psychological drama
# 29338  soylent green good movie actually ve think don...
# 29339  isn funny spot disappoint love stupid movie ex...
# 29340  absolutely terrible george isn funny kid snobb...
#
#                                            pruned_review pred_sentiment  \
# 0      river phoenix joaquin phoenix embarrasing weir...              0
# 1      usually great crazy pretty mr jones different ...              1
# 2                                           bad mediocre              0
# 3      ago single good close wonderfuly original usua...              1
# 4      wrong wrong myers ago cutesy painfully unfunny...              0
# ...                                                  ...            ...
# 29336                                   honest hollywood              1
# 29337                    absorb unsettling psychological              0
# 29338  soylent green good actually heston sneery invi...              1
# 29339  isn funny stupid good loud maybe funny flat ma...              0
# 29340  absolutely terrible george funny snobby little...              0
#
#           score
# 0      0.984501
# 1      0.999685
# 2      0.999798
# 3      0.999860
# 4      0.973535
# ...         ...
# 29336  0.999783
# 29337  0.854891
# 29338  0.997482
# 29339  0.997078
# 29340  0.996091
#
# [29304 rows x 7 columns]

# %%
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(imdb_data['sentiment'], imdb_data['pred_sentiment']))
# Out:
# 0.7703726453726454

# %%
print(classification_report(imdb_data['sentiment'], imdb_data['pred_sentiment']))
# Out:
# /home/ytchen/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#           -)       0.00      0.00      0.00         1
#            0       0.80      0.71      0.75     14368
#            1       0.75      0.83      0.79     14935
#
#     accuracy                           0.77     29304
#    macro avg       0.52      0.51      0.51     29304
# weighted avg       0.77      0.77      0.77     29304
# /home/ytchen/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ytchen/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
imdb_data.to_csv('data/pruned_review.csv', index=0)

# %%
# %%time

imdb_test_data['processed_review'] = imdb_test_data['processed_review'].astype(str)

pruned = []
for txt in tqdm(imdb_test_data['processed_review']):
    pruned.append(prune_text(txt, MAX_LEN=MAX_LEN))
# Out:
# 100%|██████████| 29341/29341 [22:42:45<00:00,  2.79s/it]
# CPU times: user 6h 7min 18s, sys: 37.3 s, total: 6h 7min 56s
# Wall time: 22h 42min 45s

# %%
imdb_test_data['pruned_review'] = pruned

# %%
# %%time

imdb_test_data['pruned_review'] = imdb_test_data['pruned_review'].astype(str)

result = []
score = []
for txt in tqdm(imdb_test_data['pruned_review']):
    result.append('0' if sentiment_analysis(txt)[0]['label'] == 'NEGATIVE' else '1')
    score.append(sentiment_analysis(txt)[0]['score'])
# Out:
# 100%|██████████| 29341/29341 [36:42<00:00, 13.32it/s]
# CPU times: user 2h 24min 23s, sys: 22.9 s, total: 2h 24min 46s
# Wall time: 36min 42s

# %%
imdb_test_data['pred_sentiment'] = result
imdb_test_data['score'] = score
imdb_test_data
# Out:
#           ID                                             review  \
# 0      22622  Robert Lansing plays a scientist experimenting...
# 1      10162  Well I've enjoy this movie, even though someti...
# 2      17468  First things first - though I believe Joel Sch...
# 3      42579  I watched this movie on the grounds that Amber...
# 4        701  A certain sexiness underlines even the dullest...
# ...      ...                                                ...
# 29336  30370  It is difficult to rate a writer/director's fi...
# 29337  18654  After watching this movie once, it quickly bec...
# 29338  47985  Even though i sat and watched the whole thing,...
# 29339   9866  Warning Spoilers following. Superb recreation ...
# 29340  35559  My, my, my: Peter Cushing and Donald Pleasance...
#
#                                         processed_review  \
# 0      robert lansing play scientist experiment pass ...
# 1      ve enjoy movie turn stereotypical situation nt...
# 2      thing believe joel schumacher well mediocre di...
# 3      watch movie ground amber benson rock nick stah...
# 4                certain sexiness underline dull tangent
# ...                                                  ...
# 29336  difficult rate writer director s effort movie ...
# 29337  watch movie quickly favorite different event h...
# 29338  sit watch thing good place big chunk informati...
# 29339  warn spoiler follow superb recreation base ant...
# 29340  peter cushing donald pleasance desperate work ...
#
#                                            pruned_review pred_sentiment  \
# 0      robert lansing solid far unintentionally dimen...              1
# 1      stereotypical nt nt different finally maybe in...              0
# 2      joel schumacher mediocre downright bad ugly jo...              0
# 3      amber nick stahl generally pretty cool bad rea...              0
# 4                                           certain dull              0
# ...                                                  ...            ...
# 29336  difficult s direct james uneven straight commo...              0
# 29337                         quickly favorite different              1
# 29338  good big inaccurate michael nt current dramati...              1
# 29339  superb antarctica real libelous scandalous can...              0
# 29340  peter cushing donald pleasance desperate horri...              0
#
#           score
# 0      0.996732
# 1      0.983873
# 2      0.996279
# 3      0.997871
# 4      0.999785
# ...         ...
# 29336  0.528997
# 29337  0.997787
# 29338  0.959790
# 29339  0.879290
# 29340  0.998017
#
# [29341 rows x 6 columns]

# %%
imdb_test_data.to_csv('pruned_test.csv', index=0)

# %%
submission = imdb_test_data[['ID', 'pred_sentiment']]
submission.rename({'pred_sentiment':'sentiment'}, axis=1,inplace=True)
submission.to_csv('./data/baseline_submission.csv', index=0)
# Out:
# /home/ytchen/.local/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
submission
# Out:
#           ID sentiment
# 0      22622         1
# 1      10162         0
# 2      17468         0
# 3      42579         0
# 4        701         0
# ...      ...       ...
# 29336  30370         0
# 29337  18654         1
# 29338  47985         1
# 29339   9866         0
# 29340  35559         0
#
# [29341 rows x 2 columns]
